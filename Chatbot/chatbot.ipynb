# %%
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
os.environ["GROQ_API_KEY"]=os.getenv("GROQ_API_KEY")

# %%
from langchain_groq import ChatGroq
model=ChatGroq(model="gemma2-9b-it")
model
# Out:
# ChatGroq(client=<groq.resources.chat.completions.Completions object at 0x000001CFD2457E00>, async_client=<groq.resources.chat.completions.AsyncCompletions object at 0x000001CFD2542270>, model_name='gemma2-9b-it', model_kwargs={}, groq_api_key=SecretStr('**********'))

# %%
model.invoke("What is BeeAI Framework")
# Out:
# ---------------------------------------------------------------------------
# ConnectError                              Traceback (most recent call last)
# File c:\Users\JE385EF\Python\Learnings\AgenticAIWorkspace\venv\Lib\site-packages\httpx\_transports\default.py:101, in map_httpcore_exceptions()
#     100 try:
# --> 101     yield
#     102 except Exception as exc:
#
# File c:\Users\JE385EF\Python\Learnings\AgenticAIWorkspace\venv\Lib\site-packages\httpx\_transports\default.py:250, in HTTPTransport.handle_request(self, request)
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#
# File c:\Users\JE385EF\Python\Learnings\AgenticAIWorkspace\venv\Lib\site-packages\httpcore\_sync\connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     255     self._close_connections(closing)
# --> 256     raise exc from None
# ...
